# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
dataset1 = pd.read_csv('ex1.csv', header=None)
dataset1.columns = ['Input', 'Output']
X = dataset1[['Input']].values
y = dataset1[['Output']].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=33)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %%
# Name: Keerthika A
# Register Number: 212224220048
class Neuralnet(nn.Module):
   def __init__(self):
        super().__init__()
        self.n1=nn.Linear(1,10)
        self.n2=nn.Linear(10,20)
        self.n3=nn.Linear(20,1)
        self.relu=nn.ReLU()
        self.history={'loss': []}
   def forward(self,x):
        x=self.relu(self.n1(x))
        x=self.relu(self.n2(x))
        x=self.n3(x)
        return x

# %%
# Initialize the Model, Loss Function, and Optimizer
ai_brain=Neuralnet()
criterion=nn.MSELoss()
optimizer=optim.RMSprop(ai_brain.parameters(),lr=0.001)

# %%
# Name: Keerthika A
# Register Number: 212224220048
def train_model(ai_brain,x_train,y_train,criteria,optmizer,epochs=4000):
    for i in range(epochs):
        optimizer.zero_grad()
        loss=criterion(ai_brain(x_train),y_train)
        loss.backward()
        optimizer.step()

        ai_brain.history['loss'].append(loss.item())
        if i%200==0:
            print(f"Epoch [{i}/epochs], loss: {loss.item():.6f}")

# %%
train_model(ai_brain, X_train_tensor, y_train_tensor, criterion, optimizer)
# Out:
# Epoch [0/epochs], loss: 27891.003906
# Epoch [200/epochs], loss: 22961.027344
# Epoch [400/epochs], loss: 15021.659180
# Epoch [600/epochs], loss: 7443.360840
# Epoch [800/epochs], loss: 3880.375488
# Epoch [1000/epochs], loss: 3566.142578
# Epoch [1200/epochs], loss: 3564.739746
# Epoch [1400/epochs], loss: 3564.380371
# Epoch [1600/epochs], loss: 3564.372314
# Epoch [1800/epochs], loss: 3564.371826
# Epoch [2000/epochs], loss: 3564.371826
# Epoch [2200/epochs], loss: 3564.372314
# Epoch [2400/epochs], loss: 3564.372559
# Epoch [2600/epochs], loss: 3564.371826
# Epoch [2800/epochs], loss: 3564.372559
# Epoch [3000/epochs], loss: 3564.372559
# Epoch [3200/epochs], loss: 3564.372314
# Epoch [3400/epochs], loss: 3564.372559
# Epoch [3600/epochs], loss: 3566.050781
# Epoch [3800/epochs], loss: 3564.372559

# %%
with torch.no_grad():
    test_loss = criterion(ai_brain(X_test_tensor), y_test_tensor)
    print(f'Test Loss: {test_loss.item():.6f}')
# Out:
# Test Loss: 12901.745117

# %%
loss_df = pd.DataFrame(ai_brain.history)

# %%
import matplotlib.pyplot as plt
loss_df.plot()
print("Name: Keerthika A\nReg No: 212224220048")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss during Training")
plt.show()
# Out:
# Name: Keerthika A
# Reg No: 212224220048

# %%
X_n1_1 = torch.tensor([[9]], dtype=torch.float32)
prediction = ai_brain(torch.tensor(scaler.transform(X_n1_1), dtype=torch.float32)).item()
print(f'Prediction: {prediction}')
# Out:
# Prediction: 144.08253479003906
